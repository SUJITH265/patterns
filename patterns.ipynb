# %%
for row in range(7):
  for col in range(5):
    if ((col==0 or col==4)and row!=0) or (row==0 or row==3) and col>0 and col<4:
      print('*',end='')
    else:
      print(end=' ')
  print()
# Out:
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *

# %%
for row in range(7):
  for col in range(5):
    if (col==0) or(col==4 and(row!=0 and row!=3 and row!=6)) or (row==0 or row==3 or row ==6) and (col>0 and col<4):
      print('*',end='')
    else:
      print(end=' ')
  print()
# Out:
# ****
# *   *
# *   *
# ****
# *   *
# *   *
# ****

# %%
for row in range(7):
  for col in range(5):
     if col==0 or col==6 and row!=0 or (row==0 or row==6 ) and col>0 and col<4:
      print('*',end='')
     else:
      print(end=' ')
  print()
# Out:
# ****
# *
# *
# *
# *
# *
# ****

# %%
i=0
j=8
for row in range(9):
  for col in range(9):
    if row==i and col==j :
      print(i,end='')
      i=i+1
      j=j-1
    elif row==col:
      print(i,end='')
    else:
      print(end=' ')
  print()
# Out:
# 0       0
#  1     1
#   2   2
#    3 3
#     4
#    5 6
#   6   7
#  7     8
# 8       9

# %%
print_s=[[" "for i in range(7)] for j in range(5)]
print_u=[[" "for i in range(7)] for j in range(5)]
print_j=[[" "for i in range(7)] for j in range(5)]
print_i=[[" "for i in range(7)] for j in range(5)]
print_t=[[" "for i in range(7)] for j in range(5)]
print_h=[[" "for i in range(7)] for j in range(5)]


for row in range(7):
  for col in range(5):
    if (row==0 or row==3 or row==6) and(col>0 and col<4) or (col==0 and row>0 and row<3) or(col==4 and row>3 and row<6):
      print('*',end='')
    else:
      print(end=" ")
  print()



for row in range(7):
  for col in range(5):
    if ((col==0 or col==4) and row!=6) or row==6 and col>0 and col<4:
      print('*',end='')
    else:
      print(end=" ")
  print()

for row in range(7):
  for col in range(5):
    if col==2 or (row==0 and col!=2)or (row==6 and col<2) :
      print('*',end='')
    else:
      print(end=' ')
  print()


for row in range(7):
  for col in range(5):
    if col==2 or (row==0 or row==6 and col!=2) :
      print('*',end='')
    else:
      print(end=' ')
  print()

for row in range(7):
  for col in range(5):
    if col==2 or (row==0) and col!=2 :
      print('*',end='')
    else:
      print(end=' ')
  print()

for row in range(7):
  for col in range(5):
    if (col==0 or col==4) or (row==3 and col>0 and col<4) :
      print('*',end='')
    else:
      print(end=" ")
  print()
# Out:
#  ***
# *
# *
#  ***
#     *
#     *
#  ***
# *   *
# *   *
# *   *
# *   *
# *   *
# *   *
#  ***
# *****
#   *
#   *
#   *
#   *
#   *
# ***
# *****
#   *
#   *
#   *
#   *
#   *
# *****
# *****
#   *
#   *
#   *
#   *
#   *
#   *
# *   *
# *   *
# *   *
# *****
# *   *
# *   *
# *   *

# %%
def expense(list1,month,str1):
    
    
            
    if month=="jan" or month=="mar" or month=="may" or month=="july" or month=="oct" or month=="dec" :
        
        expenses=23*month[str1]+4*list1['sun']+4*list1['sat']
        
        
        return expenses
        
    elif month=="feb":
        expenses=20*month[str1]+4*list1['sun']+4*list1['sat']
        
        return expenses
        
        
    else:
        
        expenses=22*month[str1]+4*list1['sun']+4*list1['sat']
        
        return expenses
        
        

month={'jan':31,'feb':28,'mar':31,'apr':30,'may':31,'jun':30,'july':31,'aug':31,'sep':30,'oct':31,'nov':30,'dec':31}
list1={'mon':3,'tue':3,'wed':3,'thu':3,'fri':3,'sat':5,
            'sun':6}
            
str1="feb"
print(expense(list1,month,str1))
# Out:
# 660

# %%
i=0
j=4
for row in range(7):
  for col in range(5):
    if col==0 or (row==col+2 and col>1):
      print('*',end='')
    elif (row==i and col==j) and col>0:
      print('*',end='')
      i=i+1
      j=j-1
    else:
      print(end=' ')
  print()

for row in range(7):
  for col in range(5):
    if col==0 or (row==0 or row==3 or row==6) and col>0:
      print('*',end='')
    else:
      print(end=' ')
  print()

for row in range(7):
  for col in range(5):
    if col==0 or (row==0 or row==3 or row==6) and col>0:
      print('*',end='')
    else:
      print(end=' ')
  print()

for row in range(7):
  for col in range(5): 
    if col==0 or (col==4 and(row!=0 and row!=3)) or (row==0 or row==3) and(col>0 and col<4):
      print('*',end='')
    else:
      print(end=' ')
  print()



for row in range(7):
  for col in range(5):
    if col==2 or (row==0) and col!=2 :
      print('*',end='')
    else:
      print(end=' ')
  print()




for row in range(7):
  for col in range(5):
    if ((col==0 or col==4)and row!=0) or (row==0 or row==3) and col>0 and col<4:
      print('*',end='')
    else:
      print(end=' ')
  print()
  
for row in range(7):
  for col in range(5):
    if ((col==0 or col==4)and row!=0) or (row==0 or row==3) and col>0 and col<4:
      print('*',end='')
    else:
      print(end=' ')
  print()



for row in range(6):
  for col in range(6):
    if col==0 or col==5 or (row==col and (col>0 and col<5)):
      print('*',end='')
    else:
      print(end=' ')
  print()


for row in range(7):
  for col in range(5):
    if ((col==0 or col==4)and row!=0) or (row==0 or row==3) and col>0 and col<4:
      print('*',end='')
    else:
      print(end=' ')
  print()
# Out:
# *   *
# *  *
# * *
# **
# * *
# *  *
# *   *
# *****
# *
# *
# *****
# *
# *
# *****
# *****
# *
# *
# *****
# *
# *
# *****
# ****
# *   *
# *   *
# ****
# *   *
# *   *
# *   *
# *****
#   *
#   *
#   *
#   *
#   *
#   *
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *
# *    *
# **   *
# * *  *
# *  * *
# *   **
# *    *
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *

# %%
print_s=[[" "for i in range(5)] for j in range(7)]
print_u=[[" "for i in range(5)] for j in range(7)]
print_j=[[" "for i in range(5)] for j in range(7)]
print_i=[[" "for i in range(5)] for j in range(7)]
print_t=[[" "for i in range(5)] for j in range(7)]
print_h=[[" "for i in range(5)] for j in range(7)]


for row in range(7):
  for col in range(5):
    if (row==0 or row==3 or row==6) and(col>0 and col<4) or (col==0 and row>0 and row<3) or(col==4 and row>3 and row<6):
      print_s[row][col]= '*'



for row in range(7):
  for col in range(5):
    if ((col==0 or col==4) and row!=6) or row==6 and col>0 and col<4:
      print_u[row][col]='*'

for row in range(7):
  for col in range(5):
    if col==2 or (row==0 and col!=2)or (row==6 and col<2) :
      print_j[row][col]='*'



for row in range(7):
  for col in range(5):
    if col==2 or (row==0 or row==6 and col!=2) :
      print_i[row][col]='*'

for row in range(7):
  for col in range(5):
    if col==2 or (row==0) and col!=2 :
     print_t[row][col]='*'

for row in range(7):
  for col in range(5):
    if (col==0 or col==4) or (row==3 and col>0 and col<4) :
      print_h[row][col]='*'

for i in range(7):
    for j in range(5):
      print(print_s[i][j],end='')
    for j in range(5):
      print(print_u[i][j],end='')
    for j in range(5):
      print(print_j[i][j],end='')
    for j in range(5):
      print(print_i[i][j],end='')
    for j in range(5):
      print(print_t[i][j],end='')
    for j in range(5):
      print(print_h[i][j],end='')
    print()
# Out:
#  *** *   *****************   *
# *    *   *  *    *    *  *   *
# *    *   *  *    *    *  *   *
#  *** *   *  *    *    *  *****
#     **   *  *    *    *  *   *
#     **   *  *    *    *  *   *
#  ***  *** ***  *****  *  *   *

# %%
print_k=[[" "for i in range(5)] for j in range(7)]
print_e=[[" "for i in range(5)] for j in range(7)]
print_e=[[" "for i in range(5)] for j in range(7)]
print_r=[[" "for i in range(5)] for j in range(7)]
print_t=[[" "for i in range(5)] for j in range(7)]
print_h=[[" "for i in range(5)] for j in range(7)]
print_a=[[" "for i in range(5)] for j in range(7)]
print_n=[[" "for i in range(6)] for j in range(6)]
print_a=[[" "for i in range(5)] for j in range(7)]

a=0
b=4
for row in range(7):
  for col in range(5):
    if col==0 or (row==col+2 and col>1):
      print_k[row][col]='*'
    elif (row==a and col==b) and col>0:
      print_k[row][col]='*'
      a=a+1
      b=b-1

for row in range(7):
  for col in range(5):
    if col==0 or (row==0 or row==3 or row==6) and col>0:
      print_e[row][col]='*'


    
for row in range(7):
  for col in range(5): 
    if col==0 or (col==4 and(row!=0 and row!=3)) or (row==0 or row==3) and(col>0 and col<4):
      print_r[row][col]='*'
for row in range(7):
  for col in range(5):
    if col==2 or (row==0) and col!=2 :
      print_t[row][col]='*'
for row in range(7):
  for col in range(5):
    if (col==0 or col==4) or (row==3 and col>0 and col<4) :
      print_h[row][col]='*'
for row in range(7):
  for col in range(5):
    if ((col==0 or col==4)and row!=0) or (row==0 or row==3) and col>0 and col<4:
      print_a[row][col]='*'
for row in range(6):
  for col in range(6):
    if col==0 or col==5 or (row==col and (col>0 and col<5)):
      print_n[row][col]='*'
for i in range(7):
    for j in range(5):
      print(print_k[i][j],end='')
    for j in range(5):
      print(print_e[i][j],end='')
    for j in range(5):
      print(print_e[i][j],end='')
    for j in range(5):
      print(print_r[i][j],end='')
    for j in range(5):
      print(print_t[i][j],end='')
    for j in range(5):
      print(print_h[i][j],end='')
    for j in range(5):
      print(print_a[i][j],end='')
    for j in range(5):
      print(print_a[i][j],end='')
    print()
for i in range(6):
    for j in range(6):
      print(print_n[i][j],end='')
    print()
# Out:
# *   *************** ******   * ***  ***
# *  * *    *    *   *  *  *   **   **   *
# * *  *    *    *   *  *  *   **   **   *
# **   **************   *  ***************
# * *  *    *    *   *  *  *   **   **   *
# *  * *    *    *   *  *  *   **   **   *
# *   ************   *  *  *   **   **   *
# *    *
# **   *
# * *  *
# *  * *
# *   **
# *    *

# %%
i=0
j=4
for row in range(6):
  for col in range(6):
    if col==0 or (row==col+2 and col>1):
      print('*',end='')
    elif (row==i and col==j) and col>0:
      print('*',end='')
      i=i+1
      j=j-1
    else:
      print(end=' ')
  print()
# Out:
# *   *
# *  *
# * *
# **
# * *
# *  *

# %%
for row in range(7):
  for col in range(5):
    if col==0 or col==4 or (row==col and (col>0 and col<4)):
      print('*',end='')
    else:
      print(end=' ')
  print()
# Out:
# *   *
# **  *
# * * *
# *  **
# *   *
# *   *
# *   *

# %%
for row in range(6):
  for col in range(6):
    if col==0 or col==5 or (row==col and (col>0 and col<5)):
      print('*',end='')
    else:
      print(end=' ')
  print()
# Out:
# *    *
# **   *
# * *  *
# *  * *
# *   **
# *    *

# %%
for row in range(7):
  for col in range(5):
    if ((col==0 or col==4)and row!=0) or (row==0 or row==3) and col>0 and col<4:
      print('*',end='')
    else:
      print(end=' ')
  print()
# Out:
#  ***
# *   *
# *   *
# *****
# *   *
# *   *
# *   *

# %%
for row in range(6):
  for col in range(6):
    if col==2 or (row==0) and col!=2 :
      print('*',end='')
    else:
      print(end=' ')
  print()
# Out:
# ******
#   *
#   *
#   *
#   *
#   *
